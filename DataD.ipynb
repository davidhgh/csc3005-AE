# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
import pandas as pd

# dataB = pd.read_csv('Meter D', sep="\t", header=None)
dataD = pd.read_csv('Meter D.csv',header=None)
dataD.columns = [
'ProfileFactor', 
'Symmetry', 
'Crossflow', 
'FlowVelocityP1', 
'FlowVelocityP2',
'FlowVelocityP3',
'FlowVelocityP4',  
'SoundSpeedP1', 
'SoundSpeedP2', 
'SoundSpeedP3', 
'SoundSpeedP4',  
'SignalStrengthP1_1', 
'SignalStrengthP1_2', 
'SignalStrengthP2_1', 
'SignalStrengthP2_2',
'SignalStrengthP3_1',
'SignalStrengthP3_2',
'SignalStrengthP4_1',
'SignalStrengthP4_2',
'SignalQualityP1_1',
'SignalQualityP1_2',
'SignalQualityP2_1',
'SignalQualityP2_2',
'SignalQualityP3_1',
'SignalQualityP3_2', 
'SignalQualityP4_1',
'SignalQualityP4_2',
'GainP1_1', 
'GainP1_2', 
'GainP2_1', 
'GainP2_2', 
'GainP3_1', 
'GainP3_2', 
'GainP4_1', 
'GainP4_2', 
'TransmitTimeP1_1', 
'TransmitTimeP1_2', 
'TransmitTimeP2_1', 
'TransmitTimeP2_2', 
'TransmitTimeP3_1', 
'TransmitTimeP3_2', 
'TransmitTimeP4_1', 
'TransmitTimeP4_2', 
'HealthState']

dataD
# Out:
#      ProfileFactor  Symmetry  Crossflow  FlowVelocityP1  FlowVelocityP2  \
# 0         1.104706  1.004679   0.994783        2.345833        2.604444
# 1         1.089401  0.997778   0.998012        3.399444        3.711111
# 2         1.079671  1.006056   0.999027        3.438056        3.714722
# 3         1.090834  1.013194   0.994911        3.399444        3.725000
# 4         1.093816  1.009716   1.003622        3.398889        3.702778
# ..             ...       ...        ...             ...             ...
# 175       4.593220  5.153846   0.123245       -0.138611       -1.703889
# 176       0.173768  0.214250   0.098034       -0.200833       -0.401389
# 177       0.049027  0.115593   0.134579       -0.281111       -0.050833
# 178      -0.053056  0.099441   0.143832       -0.386667        0.129722
# 179       0.008931  0.914347   1.184204       -2.617222        0.144167
#
#      FlowVelocityP3  FlowVelocityP4  SoundSpeedP1  SoundSpeedP2  SoundSpeedP3  \
# ...

# %%
dataD['AvgFlowVelocity'] = dataD[['FlowVelocityP1',
                                  'FlowVelocityP2',
                                  'FlowVelocityP3',
                                  'FlowVelocityP4']].mean(axis=1)
dataD['AvgSoundSpeed'] = dataD[['SoundSpeedP1',
                                'SoundSpeedP2',
                                'SoundSpeedP3',
                                'SoundSpeedP4']].mean(axis=1)
dataD['AvgSignalStrength'] = dataD[['SignalStrengthP1_1',
                                    'SignalStrengthP1_2',
                                    'SignalStrengthP2_1',
                                    'SignalStrengthP2_2',
                                    'SignalStrengthP3_1',
                                    'SignalStrengthP3_2',
                                    'SignalStrengthP4_1',
                                    'SignalStrengthP4_2']].mean(axis=1)
dataD['AvgSignalQuality'] = dataD[['SignalQualityP1_1',
                                   'SignalQualityP1_2',
                                   'SignalQualityP2_1',
                                   'SignalQualityP2_2',
                                   'SignalQualityP3_1',
                                   'SignalQualityP3_2',
                                   'SignalQualityP4_1',
                                   'SignalQualityP4_2']].mean(axis=1)

dataD['AvgGain'] = dataD[['GainP1_1',
                          'GainP1_2',
                          'GainP2_1',
                          'GainP2_2',
                          'GainP3_1',
                          'GainP3_2',
                          'GainP4_1',
                          'GainP4_2']].mean(axis=1)
dataD['AvgTransitTime'] = dataD[['TransmitTimeP1_1',
                                'TransmitTimeP1_2',
                                 'TransmitTimeP2_1',
                                 'TransmitTimeP2_2',
                                 'TransmitTimeP3_1',
                                 'TransmitTimeP3_2',
                                 'TransmitTimeP4_1',
                                 'TransmitTimeP4_2']].mean(axis=1)

# %%
dataD_df = dataD.drop(['SignalStrengthP1_1',
                       'SignalStrengthP1_2',
                       'SignalStrengthP2_1',
                       'SignalStrengthP2_2',
                       'SignalStrengthP3_1',
                       'SignalStrengthP3_2',
                       'SignalStrengthP4_1',
                       'SignalStrengthP4_2',
                       'SignalQualityP1_1',
                       'SignalQualityP1_2',
                       'SignalQualityP2_1',
                       'SignalQualityP2_2',
                       'SignalQualityP3_1',
                       'SignalQualityP3_2',
                       'SignalQualityP4_1',
                       'SignalQualityP4_2',
                       'GainP1_1',
                       'GainP1_2',
                       'GainP2_1',
                       'GainP2_2',
                       'GainP3_1',
                       'GainP3_2',
                       'GainP4_1',
                       'GainP4_2',
                       'TransmitTimeP1_1',
                       'TransmitTimeP1_2',
                       'TransmitTimeP2_1',
                       'TransmitTimeP2_2',
                       'TransmitTimeP3_1',
                       'TransmitTimeP3_2',
                       'TransmitTimeP4_1',
                       'TransmitTimeP4_2',
                       'FlowVelocityP1',
                       'FlowVelocityP2',
                       'FlowVelocityP3',
                       'FlowVelocityP4',
                       'SoundSpeedP1',
                       'SoundSpeedP2',
                       'SoundSpeedP3',
                       'SoundSpeedP4'
                       ], axis=1)

# %%
# Shift HealthState to the back
outputCol = dataD_df['HealthState']
dataD_df = dataD_df.drop(['HealthState'], axis=1)
dataD_df['HealthState'] = outputCol

dataD_df
# Out:
#      ProfileFactor  Symmetry  Crossflow  AvgFlowVelocity  AvgSoundSpeed  \
# 0         1.104706  1.004679   0.994783         2.469375    1485.864584
# 1         1.089401  0.997778   0.998012         3.559236    1486.225000
# 2         1.079671  1.006056   0.999027         3.565625    1486.381945
# 3         1.090834  1.013194   0.994911         3.539028    1486.507639
# 4         1.093816  1.009716   1.003622         3.533750    1486.652778
# ..             ...       ...        ...              ...            ...
# 175       4.593220  5.153846   0.123245        -0.550000    1520.656945
# 176       0.173768  0.214250   0.098034        -0.853264    1513.135417
# 177       0.049027  0.115593   0.134579        -0.800903    1506.310416
# 178      -0.053056  0.099441   0.143832        -0.710208    1486.756250
# 179       0.008931  0.914347   1.184204        -1.294444    1487.203473
#
#      AvgSignalStrength  AvgSignalQuality    AvgGain  AvgTransitTime  \
# ...

# %%
dataD_df_noHealthState = dataD_df.drop(['HealthState'], axis=1)
dataD_df_noHealthState
# Out:
#      ProfileFactor  Symmetry  Crossflow  AvgFlowVelocity  AvgSoundSpeed  \
# 0         1.104706  1.004679   0.994783         2.469375    1485.864584
# 1         1.089401  0.997778   0.998012         3.559236    1486.225000
# 2         1.079671  1.006056   0.999027         3.565625    1486.381945
# 3         1.090834  1.013194   0.994911         3.539028    1486.507639
# 4         1.093816  1.009716   1.003622         3.533750    1486.652778
# ..             ...       ...        ...              ...            ...
# 175       4.593220  5.153846   0.123245        -0.550000    1520.656945
# 176       0.173768  0.214250   0.098034        -0.853264    1513.135417
# 177       0.049027  0.115593   0.134579        -0.800903    1506.310416
# 178      -0.053056  0.099441   0.143832        -0.710208    1486.756250
# 179       0.008931  0.914347   1.184204        -1.294444    1487.203473
#
#      AvgSignalStrength  AvgSignalQuality    AvgGain  AvgTransitTime
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(16,10))
cor_d = dataD_df_noHealthState.corr()
sns.heatmap(cor_d, annot=True)
plt.show()

# %% [markdown]
# <b>Boxplot<b>

# %%
#Summary View of all attribute , The we will look into all the boxplot individually to trace out outliers
plt.subplots(figsize=(30,10))
ax = sns.boxplot(data=dataD_df_noHealthState, orient="h")

# %%
dataD_df_noHealthState.shape
# Out:
# (180, 9)

# %%
dataD_df_noHealthState.describe()
# Out:
#        ProfileFactor    Symmetry   Crossflow  AvgFlowVelocity  AvgSoundSpeed  \
# count     180.000000  180.000000  180.000000       180.000000     180.000000
# mean        1.411731    1.166684    1.188470         4.385636    1494.599726
# std         0.904196    3.189220    0.675639         2.158233      19.850009
# min        -2.474166  -37.780488   -2.275649        -1.294444    1477.756250
# 25%         1.085364    0.999759    0.992503         2.890260    1483.850000
# 50%         1.093996    1.005958    0.998655         4.374549    1485.563542
# 75%         1.207706    1.020066    1.007719         6.499201    1498.663715
# max         5.911308   11.191656    3.314103         8.294653    1563.770139
#
#        AvgSignalStrength  AvgSignalQuality     AvgGain  AvgTransitTime
# count         180.000000        180.000000  180.000000      180.000000
# mean           63.953781       3204.505652    9.323387      137.105698
# ...

# %%
# Identifying Outliers with Skewness
print(dataD_df_noHealthState.skew())
# Out:
# ProfileFactor        1.786843
# Symmetry            -9.936270
# Crossflow            0.121624
# AvgFlowVelocity     -0.494428
# AvgSoundSpeed        1.989851
# AvgSignalStrength   -1.561399
# AvgSignalQuality    -1.676003
# AvgGain              1.480285
# AvgTransitTime      -1.913671
# dtype: float64

# %%
# remove Outliers Using IQR: Upper whisker
from scipy.stats import iqr

Q1 = dataD_df.quantile(0.25)
Q3 = dataD_df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)


cleandf_d = dataD_df[~((dataD_df < (Q1 - 1.5 * IQR)) |(dataD_df > (Q3 + 1.5 * IQR))).any(axis=1)]
cleandf_d.shape
# Out:
# ProfileFactor          0.122342
# Symmetry               0.020307
# Crossflow              0.015216
# AvgFlowVelocity        3.608941
# AvgSoundSpeed         14.813715
# AvgSignalStrength      2.500000
# AvgSignalQuality     577.595486
# AvgGain               11.075000
# AvgTransitTime         1.037595
# HealthState            3.000000
# dtype: float64
# (125, 10)

# %%
cleandf_d_noHealthState = cleandf_d.drop(['HealthState'], axis=1)

plt.figure(figsize=(16,10))
cor_d = cleandf_d_noHealthState.corr()
sns.heatmap(cor_d, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
sns.pairplot(cleandf_d_noHealthState, diag_kind="kde")

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# KNN
from sklearn.neighbors import KNeighborsClassifier

# Naive Bayes
from sklearn.naive_bayes import GaussianNB

# SVC
from sklearn.svm import SVC
cleandf_d
# Out:
#      ProfileFactor  Symmetry  Crossflow  AvgFlowVelocity  AvgSoundSpeed  \
# 0         1.104706  1.004679   0.994783         2.469375    1485.864584
# 1         1.089401  0.997778   0.998012         3.559236    1486.225000
# 2         1.079671  1.006056   0.999027         3.565625    1486.381945
# 3         1.090834  1.013194   0.994911         3.539028    1486.507639
# 4         1.093816  1.009716   1.003622         3.533750    1486.652778
# ..             ...       ...        ...              ...            ...
# 124       1.107886  1.011329   1.002777         6.510000    1484.476389
# 125       1.099712  1.007197   1.007884         6.526458    1484.690973
# 126       1.119688  1.010656   0.998256         6.525694    1484.954861
# 127       1.110917  1.019035   1.000059         7.064097    1485.309028
# 128       1.114358  1.001870   0.979336         7.583056    1485.738889
#
#      AvgSignalStrength  AvgSignalQuality   AvgGain  AvgTransitTime  \
# ...

# %%
def usingSVC(df, colSize):
    # Split data
    X = df.iloc[:,0:colSize].values
    y = df.iloc[:,colSize].values
    # split dataset 80 20
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)
    # split dataset 70 30
    X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X, y, random_state=0, test_size=0.3)

    print("Split dataset 80:20")
    print(f"No. of training dataset (X): {len(X_train)}, No. of testing dataset: {len(X_test)}")
    print(f"No. of training dataset (y): {len(y_train)}, No. of testing dataset: {len(y_test)}")
    print()
    print("Split dataset 70:30")
    print(f"No. of training dataset (X): {len(X_train_2)}, No. of testing dataset: {len(X_test_2)}")
    print(f"No. of training dataset (y): {len(y_train_2)}, No. of testing dataset: {len(y_test_2)}")

    ## SVC 
    #Feature scaling
    sc_X = StandardScaler()

    # Split dataset 80:20
    X_train_scale = sc_X.fit_transform(X_train)
    X_test_scale = sc_X.transform(X_test)
    # Split dataset 70 30
    X_train_2_scale = sc_X.fit_transform(X_train_2)
    X_test_2_scale = sc_X.transform(X_test_2)


    ## SVC 
    svc1 = SVC() 

    # Without Feature scaling
    y_pred = svc1.fit(X_train,y_train).predict(X_test)
    y_pred_2 = svc1.fit(X_train_2,y_train_2).predict(X_test_2)

    # With Feature scaling
    y_pred_scale = svc1.fit(X_train_scale,y_train).predict(X_test_scale)
    y_pred_2_scale = svc1.fit(X_train_2_scale,y_train_2).predict(X_test_2_scale)
    print()
    print("===============================================================")
    print("|                             SVC                             |")
    print("===============================================================")

    print("=====================Without Feature scaling===================")
    print("Split dataset 80:20")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test.shape[0], (y_test != y_pred).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
    print()
    print("Split dataset 70:30")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_2.shape[0], (y_test_2 != y_pred_2).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test_2, y_pred_2)))

    print("======================With Feature scaling=====================")
    # With Feature scaling
    print("Split dataset 80:20")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_scale.shape[0], (y_test != y_pred_scale).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test, y_pred_scale)))
    print()
    print("Split dataset 70:30")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_2_scale.shape[0], (y_test_2 != y_pred_2_scale).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test_2, y_pred_2_scale)))

usingSVC(dataD_df, 9)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
#
# ...
# |                             SVC                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 15
# Accuracy score: 0.5833333333333334
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 23
# Accuracy score: 0.5740740740740741
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 12
# Accuracy score: 0.6666666666666666
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 20
# Accuracy score: 0.6296296296296297

# %%
def useKNN(df, colSize):
    # Split data
    X = df.iloc[:,0:colSize].values
    y = df.iloc[:,colSize].values
    # split dataset 80 20
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)
    # split dataset 70 30
    X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X, y, random_state=0, test_size=0.3)

    print("Split dataset 80:20")
    print(f"No. of training dataset (X): {len(X_train)}, No. of testing dataset: {len(X_test)}")
    print(f"No. of training dataset (y): {len(y_train)}, No. of testing dataset: {len(y_test)}")
    print()
    print("Split dataset 70:30")
    print(f"No. of training dataset (X): {len(X_train_2)}, No. of testing dataset: {len(X_test_2)}")
    print(f"No. of training dataset (y): {len(y_train_2)}, No. of testing dataset: {len(y_test_2)}")

    ## KNN 
    #Feature scaling
    sc_X = StandardScaler()

    # Split dataset 80:20
    X_train_scale = sc_X.fit_transform(X_train)
    X_test_scale = sc_X.transform(X_test)
    # Split dataset 70 30
    X_train_2_scale = sc_X.fit_transform(X_train_2)
    X_test_2_scale = sc_X.transform(X_test_2)


    # Define the model: Init K-NN
    classifier = KNeighborsClassifier(n_neighbors=11, p=2,metric='euclidean')

    # Without Feature scaling
    y_pred = classifier.fit(X_train,y_train).predict(X_test)
    y_pred_2 = classifier.fit(X_train_2,y_train_2).predict(X_test_2)

    # With Feature scaling
    y_pred_scale = classifier.fit(X_train_scale,y_train).predict(X_test_scale)
    y_pred_2_scale = classifier.fit(X_train_2_scale,y_train_2).predict(X_test_2_scale)

    print("===============================================================")
    print("|                             KNN                             |")
    print("===============================================================")

    print("=====================Without Feature scaling===================")
    print("Split dataset 80:20")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test.shape[0], (y_test != y_pred).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
    print()
    print("Split dataset 70:30")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_2.shape[0], (y_test_2 != y_pred_2).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test_2, y_pred_2)))

    print("======================With Feature scaling=====================")
    # With Feature scaling
    print("Split dataset 80:20")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_scale.shape[0], (y_test != y_pred_scale).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test, y_pred_scale)))
    print()
    print("Split dataset 70:30")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_2_scale.shape[0], (y_test_2 != y_pred_2_scale).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test_2, y_pred_2_scale)))

useKNN(dataD_df, 9)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
# ...
# |                             KNN                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 9
# Accuracy score: 0.75
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 11
# Accuracy score: 0.7962962962962963
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 11
# Accuracy score: 0.6944444444444444
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 18
# Accuracy score: 0.6666666666666666

# %%
def usingGuassianNaiveBayes(df, colSize):
    # Split data
    X = df.iloc[:,0:colSize].values
    y = df.iloc[:,colSize].values
    # split dataset 80 20
    X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.2)
    # split dataset 70 30
    X_train_2, X_test_2, y_train_2, y_test_2 = train_test_split(X, y, random_state=0, test_size=0.3)

    print("Split dataset 80:20")
    print(f"No. of training dataset (X): {len(X_train)}, No. of testing dataset: {len(X_test)}")
    print(f"No. of training dataset (y): {len(y_train)}, No. of testing dataset: {len(y_test)}")
    print()
    print("Split dataset 70:30")
    print(f"No. of training dataset (X): {len(X_train_2)}, No. of testing dataset: {len(X_test_2)}")
    print(f"No. of training dataset (y): {len(y_train_2)}, No. of testing dataset: {len(y_test_2)}")

    ## KNN 
    #Feature scaling
    sc_X = StandardScaler()

    # Split dataset 80:20
    X_train_scale = sc_X.fit_transform(X_train)
    X_test_scale = sc_X.transform(X_test)
    # Split dataset 70 30
    X_train_2_scale = sc_X.fit_transform(X_train_2)
    X_test_2_scale = sc_X.transform(X_test_2)

    # Gussian Naive Bayes
    gnb = GaussianNB()

    # Without Feature scaling
    y_pred = gnb.fit(X_train,y_train).predict(X_test)
    y_pred_2 = gnb.fit(X_train_2,y_train_2).predict(X_test_2)

    # With Feature scaling
    y_pred_scale = gnb.fit(X_train_scale,y_train).predict(X_test_scale)
    y_pred_2_scale = gnb.fit(X_train_2_scale,y_train_2).predict(X_test_2_scale)

    print("===============================================================")
    print("|                    Gussian Naive Bayes                      |")
    print("===============================================================")

    print("=====================Without Feature scaling===================")
    print("Split dataset 80:20")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test.shape[0], (y_test != y_pred).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test, y_pred)))
    print()
    print("Split dataset 70:30")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_2.shape[0], (y_test_2 != y_pred_2).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test_2, y_pred_2)))

    print("======================With Feature scaling=====================")
    # With Feature scaling
    print("Split dataset 80:20")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_scale.shape[0], (y_test != y_pred_scale).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test, y_pred_scale)))
    print()
    print("Split dataset 70:30")
    print("Number of mislabeled points out of a total %d points : %d"% (X_test_2_scale.shape[0], (y_test_2 != y_pred_2_scale).sum()))
    print("Accuracy score: " + str(accuracy_score(y_test_2, y_pred_2_scale)))

usingGuassianNaiveBayes(dataD_df, 9)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
# ...
# |                    Gussian Naive Bayes                      |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 8
# Accuracy score: 0.7777777777777778
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 12
# Accuracy score: 0.7777777777777778
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 8
# Accuracy score: 0.7777777777777778
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 10
# Accuracy score: 0.8148148148148148

# %% [markdown]
# <b>Testing multiple combination of features<b>

# %%
dataD2_df_no_AvgSignalQuality = dataD_df.drop(['AvgSignalQuality'], axis=1)
dataD2_df_no_AvgSignalStrength = dataD_df.drop(['AvgSignalStrength'], axis=1)
dataD2_df_no_AvgTransitTime = dataD_df.drop(['AvgTransitTime'], axis=1)
dataD2_df_no_AvgSoundSpeed = dataD_df.drop(['AvgSoundSpeed'], axis=1)

# dataB2_df_no_MeterPerformance.shape[1]

dataD2_df_no_AvgSoundSpeed
# Out:
#      ProfileFactor  Symmetry  Crossflow  AvgFlowVelocity  AvgSignalStrength  \
# 0         1.104706  1.004679   0.994783         2.469375              65.75
# 1         1.089401  0.997778   0.998012         3.559236              65.75
# 2         1.079671  1.006056   0.999027         3.565625              65.75
# 3         1.090834  1.013194   0.994911         3.539028              65.75
# 4         1.093816  1.009716   1.003622         3.533750              65.75
# ..             ...       ...        ...              ...                ...
# 175       4.593220  5.153846   0.123245        -0.550000              55.00
# 176       0.173768  0.214250   0.098034        -0.853264              55.00
# 177       0.049027  0.115593   0.134579        -0.800903              55.00
# 178      -0.053056  0.099441   0.143832        -0.710208              55.00
# 179       0.008931  0.914347   1.184204        -1.294444              55.00
#
# ...

# %%
# usingSVC(dataB2_df_no_MeterPerformance, 11)
useKNN(dataD2_df_no_AvgSoundSpeed, 8)
# usingGuassianNaiveBayes(dataB2_df_no_MeterPerformance, 11)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
# ...
# |                             KNN                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 9
# Accuracy score: 0.75
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 12
# Accuracy score: 0.7777777777777778
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 7
# Accuracy score: 0.8055555555555556
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 16
# Accuracy score: 0.7037037037037037

# %%
useKNN(dataD2_df_no_AvgSignalQuality, 8)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
# ...
# |                             KNN                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 10
# Accuracy score: 0.7222222222222222
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 14
# Accuracy score: 0.7407407407407407
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 9
# Accuracy score: 0.75
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 16
# Accuracy score: 0.7037037037037037

# %%
useKNN(dataD2_df_no_AvgTransitTime, 8)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
# ...
# |                             KNN                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 9
# Accuracy score: 0.75
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 11
# Accuracy score: 0.7962962962962963
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 8
# Accuracy score: 0.7777777777777778
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 16
# Accuracy score: 0.7037037037037037

# %% [markdown]
# <b>Trying out PCA again<b>

# %%
# PCA
from sklearn.decomposition import PCA
from sklearn import preprocessing

# dataB2_df
def usePCA_correlation(df, numOfComponent):
    # normalize data
    data_scaled = pd.DataFrame(preprocessing.scale(df),columns = df.columns) 

    # PCA
    pca = PCA(n_components=numOfComponent)
    pca.fit_transform(data_scaled)

    listLabel = []
    for i in range(0,numOfComponent):
        listLabel.append(f"PC-{i+1}")

    # Dump components relations with features:
    print(pd.DataFrame(pca.components_,columns=data_scaled.columns,index = listLabel))


usePCA_correlation(dataD_df,2)
# Out:
#       ProfileFactor  Symmetry  Crossflow  AvgFlowVelocity  AvgSoundSpeed  \
# PC-1       0.282443  0.040031   0.224391        -0.193061       0.382581
# PC-2      -0.280034 -0.248473  -0.558957        -0.463944      -0.237502
#
#       AvgSignalStrength  AvgSignalQuality   AvgGain  AvgTransitTime  \
# PC-1          -0.387270         -0.371590  0.380807       -0.379174
# PC-2          -0.246182         -0.301792  0.238502        0.255507
#
#       HealthState
# PC-1     0.328309
# PC-2     0.043666

# %%
dataD_full = pd.read_csv('Meter D.csv',header=None)
dataD_full.columns = [
'ProfileFactor', 
'Symmetry', 
'Crossflow', 
'FlowVelocityP1', 
'FlowVelocityP2',
'FlowVelocityP3',
'FlowVelocityP4',  
'SoundSpeedP1', 
'SoundSpeedP2', 
'SoundSpeedP3', 
'SoundSpeedP4',  
'SignalStrengthP1_1', 
'SignalStrengthP1_2', 
'SignalStrengthP2_1', 
'SignalStrengthP2_2',
'SignalStrengthP3_1',
'SignalStrengthP3_2',
'SignalStrengthP4_1',
'SignalStrengthP4_2',
'SignalQualityP1_1',
'SignalQualityP1_2',
'SignalQualityP2_1',
'SignalQualityP2_2',
'SignalQualityP3_1',
'SignalQualityP3_2', 
'SignalQualityP4_1',
'SignalQualityP4_2',
'GainP1_1', 
'GainP1_2', 
'GainP2_1', 
'GainP2_2', 
'GainP3_1', 
'GainP3_2', 
'GainP4_1', 
'GainP4_2', 
'TransmitTimeP1_1', 
'TransmitTimeP1_2', 
'TransmitTimeP2_1', 
'TransmitTimeP2_2', 
'TransmitTimeP3_1', 
'TransmitTimeP3_2', 
'TransmitTimeP4_1', 
'TransmitTimeP4_2', 
'HealthState']

dataD_full
# Out:
#      ProfileFactor  Symmetry  Crossflow  FlowVelocityP1  FlowVelocityP2  \
# 0         1.104706  1.004679   0.994783        2.345833        2.604444
# 1         1.089401  0.997778   0.998012        3.399444        3.711111
# 2         1.079671  1.006056   0.999027        3.438056        3.714722
# 3         1.090834  1.013194   0.994911        3.399444        3.725000
# 4         1.093816  1.009716   1.003622        3.398889        3.702778
# ..             ...       ...        ...             ...             ...
# 175       4.593220  5.153846   0.123245       -0.138611       -1.703889
# 176       0.173768  0.214250   0.098034       -0.200833       -0.401389
# 177       0.049027  0.115593   0.134579       -0.281111       -0.050833
# 178      -0.053056  0.099441   0.143832       -0.386667        0.129722
# 179       0.008931  0.914347   1.184204       -2.617222        0.144167
#
#      FlowVelocityP3  FlowVelocityP4  SoundSpeedP1  SoundSpeedP2  SoundSpeedP3  \
# ...

# %%
#dataD_full = dataD_full.drop(["HealthState"], axis=1)

# %%
usePCA_correlation(dataD_full,2)
# Out:
#       ProfileFactor  Symmetry  Crossflow  FlowVelocityP1  FlowVelocityP2  \
# PC-1       0.097520 -0.001562   0.046179       -0.079859       -0.085657
# PC-2      -0.148231 -0.099983  -0.295093       -0.231207       -0.224976
#
#       FlowVelocityP3  FlowVelocityP4  SoundSpeedP1  SoundSpeedP2  \
# PC-1       -0.080280       -0.161598      0.136182     -0.030648
# PC-2       -0.207164        0.064297     -0.104815     -0.156081
#
#       SoundSpeedP3  SoundSpeedP4  SignalStrengthP1_1  SignalStrengthP1_2  \
# PC-1      0.052257      0.150852           -0.196904           -0.197034
# PC-2     -0.251309     -0.188511           -0.012565           -0.013620
#
#       SignalStrengthP2_1  SignalStrengthP2_2  SignalStrengthP3_1  \
# PC-1           -0.193602           -0.193605           -0.193150
# PC-2           -0.104785           -0.103504           -0.010152
#
#       SignalStrengthP3_2  SignalStrengthP4_1  SignalStrengthP4_2  \
# ...

# %%
usingGuassianNaiveBayes(dataD_full, 43)
#dataD_full
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
# ...
# |                    Gussian Naive Bayes                      |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 4
# Accuracy score: 0.8888888888888888
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 5
# Accuracy score: 0.9074074074074074
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 4
# Accuracy score: 0.8888888888888888
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 5
# Accuracy score: 0.9074074074074074

# %%
usingGuassianNaiveBayes(cleandf_d, 9)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 100, No. of testing dataset: 25
# No. of training dataset (y): 100, No. of testing dataset: 25
#
# Split dataset 70:30
# No. of training dataset (X): 87, No. of testing dataset: 38
# No. of training dataset (y): 87, No. of testing dataset: 38
# ...
# |                    Gussian Naive Bayes                      |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 25 points : 3
# Accuracy score: 0.88
#
# Split dataset 70:30
# Number of mislabeled points out of a total 38 points : 14
# Accuracy score: 0.631578947368421
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 25 points : 3
# Accuracy score: 0.88
#
# Split dataset 70:30
# Number of mislabeled points out of a total 38 points : 14
# Accuracy score: 0.631578947368421

# %%
usingSVC(cleandf_d, 9)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 100, No. of testing dataset: 25
# No. of training dataset (y): 100, No. of testing dataset: 25
#
# Split dataset 70:30
# No. of training dataset (X): 87, No. of testing dataset: 38
# No. of training dataset (y): 87, No. of testing dataset: 38
#
# ...
# |                             SVC                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 25 points : 15
# Accuracy score: 0.4
#
# Split dataset 70:30
# Number of mislabeled points out of a total 38 points : 23
# Accuracy score: 0.39473684210526316
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 25 points : 7
# Accuracy score: 0.72
#
# Split dataset 70:30
# Number of mislabeled points out of a total 38 points : 13
# Accuracy score: 0.6578947368421053

# %%
usingSVC(dataD_full, 43)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
#
# ...
# |                             SVC                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 15
# Accuracy score: 0.5833333333333334
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 23
# Accuracy score: 0.5740740740740741
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 10
# Accuracy score: 0.7222222222222222
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 16
# Accuracy score: 0.7037037037037037

# %%
useKNN(cleandf_d, 9)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 100, No. of testing dataset: 25
# No. of training dataset (y): 100, No. of testing dataset: 25
#
# Split dataset 70:30
# No. of training dataset (X): 87, No. of testing dataset: 38
# No. of training dataset (y): 87, No. of testing dataset: 38
# ...
# |                             KNN                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 25 points : 9
# Accuracy score: 0.64
#
# Split dataset 70:30
# Number of mislabeled points out of a total 38 points : 14
# Accuracy score: 0.631578947368421
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 25 points : 13
# Accuracy score: 0.48
#
# Split dataset 70:30
# Number of mislabeled points out of a total 38 points : 16
# Accuracy score: 0.5789473684210527

# %%
useKNN(dataD_full, 43)
# Out:
# Split dataset 80:20
# No. of training dataset (X): 144, No. of testing dataset: 36
# No. of training dataset (y): 144, No. of testing dataset: 36
#
# Split dataset 70:30
# No. of training dataset (X): 126, No. of testing dataset: 54
# No. of training dataset (y): 126, No. of testing dataset: 54
# ...
# |                             KNN                             |
# ...
# =====================Without Feature scaling===================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 8
# Accuracy score: 0.7777777777777778
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 13
# Accuracy score: 0.7592592592592593
# ======================With Feature scaling=====================
# Split dataset 80:20
# Number of mislabeled points out of a total 36 points : 7
# Accuracy score: 0.8055555555555556
#
# Split dataset 70:30
# Number of mislabeled points out of a total 54 points : 13
# Accuracy score: 0.7592592592592593

# %%
plt.scatter(dataD_full["Symmetry"], dataD_full["Symmetry"], c="red", edgecolor='k')
plt.scatter(dataD_full["Crossflow"], dataD_full["Crossflow"],c="yellow", edgecolor='k')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Plot of data:Feature 1 verus Feature 2")
# Out:
# Text(0.5, 1.0, 'Plot of data:Feature 1 verus Feature 2')

# %%
dataD_noHealthState = dataD.drop(["HealthState"], axis=1)
X=dataD_noHealthState.to_numpy()
Y=dataD[["HealthState"]].to_numpy()
Y=Y.reshape(-1)
reds = Y == 1
black = Y != 1
plt.scatter(X[reds, 0], X[reds, 1], c="red", edgecolor='k')
plt.scatter(X[black, 0], X[black, 1], c="yellow", edgecolor='k')
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.title("Plot of data:Feature 1 verus Feature 2")
# Out:
# Text(0.5, 1.0, 'Plot of data:Feature 1 verus Feature 2')
